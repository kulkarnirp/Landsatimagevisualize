# %%
import os
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
import rasterio as rio
from rasterio.plot import show
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es

# %%
#fp = r"/home/rushikesh/PhD/Global_Lakes/Satellite_Data/Lake_kasuminigura.tif"
fp = r"/home/rushikesh/PhD/Global_Lakes/DEM/Lake_Tohoe/LakeTohoe_DEM.tif"

# %%
#Landsat_KS = rasterio.open(fp)
Landsat_Tohoe = rio.open(fp)

# %%
#show(Landsat_KS, with_bounds = True, title ='Landsat 8 Lake Kasumigaura')
plt.savefig("/home/rushikesh/PhD/Global_Lakes/DEM/Lake_Tohoe/Tohoe_DEM_Map.pdf")
show(Landsat_Tohoe, with_bounds = True, title ='Lake Tohoe DEM')
